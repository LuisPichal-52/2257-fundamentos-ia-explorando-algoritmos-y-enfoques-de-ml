# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2257-fundamentos-ia-explorando-algoritmos-y-enfoques-de-ml/blob/main/fundamentos_ia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Clase 1**
#
# ## Aprendizaje Supervisado - Clasificación
